# %%
#[런타임유형변경] > [GPU] 설정해주기!!!!!!!!!!
import torch
import torchvision
import torch.nn


torch.cuda.is_available()
# Out:
# True

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip3 install --upgrade torch torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !git clone https://github.com/Dabinishere/PNGAN.git
# %cd PNGAN
# Out:
# Cloning into 'PNGAN'...
# remote: Enumerating objects: 449, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 449 (delta 24), reused 0 (delta 0), pack-reused 410
# Receiving objects: 100% (449/449), 45.86 MiB | 37.96 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# /content/PNGAN

# %%
# !sudo apt-get install cmake build-essential libjpeg-dev libpng-dev
# !conda create -n pytorch1 python=3.7
# !conda activate pytorch1
# !conda install pytorch=1.7 torchvision=0.8.0 cudatoolkit=9.0 -c pytorch
# !pip install matplotlib scikit-image opencv-python yacs joblib natsort h5py tqdm
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# libpng-dev is already the newest version (1.6.37-2).
# build-essential is already the newest version (12.8ubuntu1.1).
# cmake is already the newest version (3.16.3-1ubuntu1.20.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# /bin/bash: conda: command not found
# /bin/bash: conda: command not found
# /bin/bash: conda: command not found
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import gdown
gdown.download('https://drive.google.com/uc?id=1mUNEC9-d1urRKO2b9HZ61DStloo2XB5V', "./pre-trained/", quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1mUNEC9-d1urRKO2b9HZ61DStloo2XB5V
# To: /content/PNGAN/pre-trained/MIRNet_polyu.pth
# 100%|██████████| 382M/382M [00:05<00:00, 64.6MB/s]
# './pre-trained/MIRNet_polyu.pth'

# %%
import gdown
gdown.download('https://drive.google.com/uc?id=1JTQU3zwMxmHWEaqjCpCps69t312lNDWN', "./pre-trained/", quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1JTQU3zwMxmHWEaqjCpCps69t312lNDWN
# To: /content/PNGAN/pre-trained/MIRNet_sidd.pth
# 100%|██████████| 382M/382M [00:06<00:00, 56.4MB/s]
# './pre-trained/MIRNet_sidd.pth'

# %%
import gdown
gdown.download('https://drive.google.com/uc?id=14cDwV3sNaBDFUiOvzNF6mc4IJ8AN6suB', "./pre-trained/", quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=14cDwV3sNaBDFUiOvzNF6mc4IJ8AN6suB
# To: /content/PNGAN/pre-trained/RIDNet_nam.pth
# 100%|██████████| 18.1M/18.1M [00:00<00:00, 30.1MB/s]
# './pre-trained/RIDNet_nam.pth'

# %% [markdown]
# ##dataset 넣기
# 1. 자기 dataset 폴더를 groundtruth로 이름변경 후 zip파일로 다운로드
# 2. test.zip으로 zip파일 이름변경 후 그대로 본인 구글드라이브에 업로드
# 3. 업로드한 zip파일을 링크가있는모든사용자 viewer로 설정
# 4. ID를 복사

# %%
# !pwd
# !mkdir ./datasets/sheep ##person을 자기 카테고리로 바꿀것
# !mkdir ./results/sheep ##person을 자기 카테고리로 바꿀것
# Out:
# /content/PNGAN

# %%
##데이터 폴더명이 groundtruth, ZIp파일명이 test
## test.zip
##      |--- groundtruth
##            |--- 001.png
##            |--- 002.png


import os
import gdown
import shutil

### Google drive IDs ######
test = '1waj3yBHrf23nvfnd3pISTF1Tufx3_uWF'      ## https://drive.google.com/file/d/1XaI2JGbcP8KE2Tyh5UR3iivKeLj8xSuM/view?usp=sharing



### input만들기 ###
print('Testing Data!')
gdown.download(id=test, output='datasets/sheep/test.zip', quiet=False)
#os.system(f'gdrive download {test} --path datasets/person') ### person을 자기 카테고리로 변경할 것
print('Extracting data...')
shutil.unpack_archive('datasets/sheep/test.zip', 'datasets/sheep') ### person을 자기 카테고리로 변경할 것
os.remove('datasets/sheep/test.zip')
os.rename('datasets/sheep/groundtruth','datasets/sheep/input')


### groundtruth만들기 ###
print('Testing Data!')
gdown.download(id=test, output='datasets/sheep/test.zip', quiet=False)
#os.system(f'gdrive download {test} --path datasets/person') ### person을 자기 카테고리로 변경할 것
print('Extracting data...')
shutil.unpack_archive('datasets/sheep/test.zip', 'datasets/sheep') ### person을 자기 카테고리로 변경할 것
os.remove('datasets/sheep/test.zip')
# Out:
# Testing Data!
# Downloading...
# From: https://drive.google.com/uc?id=1waj3yBHrf23nvfnd3pISTF1Tufx3_uWF
# To: /content/PNGAN/datasets/sheep/test.zip
# 100%|██████████| 415M/415M [00:05<00:00, 75.0MB/s]
# Extracting data...
# Testing Data!
# Downloading...
# From: https://drive.google.com/uc?id=1waj3yBHrf23nvfnd3pISTF1Tufx3_uWF
# To: /content/PNGAN/datasets/sheep/test.zip
# 100%|██████████| 415M/415M [00:01<00:00, 264MB/s]
# Extracting data...

# %% [markdown]
# ##TEST

# %%
# For SIDD denoising
# !python test_denoiser.py --method mirnet --input_dir ./datasets/sheep/ --result_dir ./results/sheep/ --weights ./pre-trained/MIRNet_sidd.pth

### input_dir랑 result_dir 뒤쪽 ./datasets/person/ 에서 person을 자기 카테고리로 바꿀 것
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ===>Testing using weights:  ./pre-trained/MIRNet_sidd.pth
# 100% 1008/1008 [25:33<00:00,  1.52s/it]
# PSNR: 32.88
# SSIM: 0.880

# %%
# !zip -r /content/drive/MyDrive/sheep.zip /content/PNGAN/results/sheep/ ##person을 자기 카테고리로 바꿀 것
# Out:
#   adding: content/PNGAN/results/sheep/ (stored 0%)
#   adding: content/PNGAN/results/sheep/sheep (947).png (deflated 7%)
#   adding: content/PNGAN/results/sheep/sheep (571).png (deflated 5%)
#   adding: content/PNGAN/results/sheep/sheep (72).png (deflated 3%)
#   adding: content/PNGAN/results/sheep/sheep (907).png (deflated 3%)
#   adding: content/PNGAN/results/sheep/sheep (198).png (deflated 4%)
#   adding: content/PNGAN/results/sheep/sheep (667).png (deflated 3%)
#   adding: content/PNGAN/results/sheep/sheep (782).png (deflated 3%)
#   adding: content/PNGAN/results/sheep/sheep (370).png (deflated 4%)
#   adding: content/PNGAN/results/sheep/sheep (971).png (deflated 5%)
#   adding: content/PNGAN/results/sheep/sheep (93).png (deflated 2%)
#   adding: content/PNGAN/results/sheep/sheep (111).png (deflated 4%)
#   adding: content/PNGAN/results/sheep/sheep (103).png (deflated 4%)
#   adding: content/PNGAN/results/sheep/sheep (754).png (deflated 2%)
# ...

# %%
# For SIDD denoising
#!python test_denoiser.py --method mirnet --input_dir ./datasets/SIDD/ --result_dir ./results/SIDD/noise_removal/ --weights ./pre-trained/MIRNet_sidd.pth

# For PolyU denoising
#!python test_denoiser.py --method mirnet --input_dir ./datasets/PolyU/ --result_dir ./results/PolyU/noise_removal/ --weights ./pre-trained/MIRNet_polyu.pth

# For Nam denoising
#!python test_denoiser.py --method ridnet --input_dir ./datasets/Nam/ --result_dir ./results/Nam/noise_removal/ --weights ./pre-trained/RIDNet_nam.pth
